# %%
import os

with open("nebius_api_key", "r") as file:
    nebius_api_key = file.read().strip()

os.environ["NEBIUS_API_KEY"] = nebius_api_key

from openai import OpenAI

# Nebius uses the same OpenAI() class, but with additional details
nebius_client = OpenAI(
    base_url="https://api.studio.nebius.ai/v1/",
    api_key=os.environ.get("NEBIUS_API_KEY"),
)

llm_model = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# %%
def prettify_string(text, max_line_length=80):
    """Prints a string with line breaks at spaces to prevent horizontal scrolling.

    Args:
        text: The string to print.
        max_line_length: The maximum length of each line.
    """

    output_lines = []
    lines = text.split("\n") #Split the chunk of text retrieved from LLM into lines
    for line in lines:       #Loop all the lines
        current_line = ""
        words = line.split() #Split the lines into words separate by whitespace
        for word in words:
            if len(current_line) + len(word) + 1 <= max_line_length:
                current_line += word + " "
            else:
                output_lines.append(current_line.strip())
                current_line = word + " "
        output_lines.append(current_line.strip())  # Append the last line
    return "\n".join(output_lines)

# %%
def answer_with_llm(prompt: str,
                    system_prompt,
                    max_tokens=512,
                    client=nebius_client,
                    model=llm_model,
                    prettify=True,
                    temperature=0.7) -> str:

    messages = []

    if system_prompt:
        messages.append(
            {
                "role": "system",
                "content": system_prompt
            }
        )

    messages.append(
        {
            "role": "user",
            "content": prompt
        }
    )

    completion = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=max_tokens,
        temperature=temperature
    )
    if prettify:
        return prettify_string(completion.choices[0].message.content)
    else:
        return completion.choices[0].message.content

# %%
# Step 1: System prompt   
system_prompt = """
You are my helpful assistant.
"""

# %%
# Step 2: Well known prompt and long tail prompt    
prompt_moonland = """
Summarize the outcome of the Apollo 11 moon landing and provide 3 credible sources for your information
"""

prompt_partior_longtail = """
Summarize the latest advancements on Partior blockchain and how it send, receive and handles cross border transfers between banks and customers.
"""

# %%
result = answer_with_llm(prompt_moonland,system_prompt)
print("\n")
print("Well-known event\n")
print("==============================================================\n")
print(result)
# Out:
# Well-known event
#
# ==============================================================
#
# The Apollo 11 moon landing was a historic spaceflight mission that successfully
# landed astronauts on the surface of the Moon. Here's a summary of the outcome:
#
# **Mission Overview:**
#
# * Date: July 20, 1969
# * Crew: Neil Armstrong, Edwin "Buzz" Aldrin, and Michael Collins
# * Objective: To land astronauts on the Moon's surface and return safely to
# Earth
# * Outcome: Mission accomplished! The Eagle lunar module, piloted by Neil
# Armstrong, landed on the Moon's surface in the Sea of Tranquility (Latin: Mare
# Tranquillitatis) at 20:17 UTC on July 20, 1969.
#
# **Key Events:**
#
# * At 21:17 UTC, Armstrong radioed back to Mission Control on Earth, "Houston,
# Tranquility Base here. The Eagle has landed."
# * At 02:56 UTC on July 21, Armstrong became the first person to set foot on the
# Moon, famously declaring, "That's one small step for man, one giant leap for
# mankind."
# * After spending about 2.5 hours on the Moon's surface, collecting samples and
# conducting experiments, the astronauts returned to the Eagle lunar module and
# lifted off from the Moon at 23:54 UTC.
#
# **Outcome:**
#
# * The Apollo 11 spacecraft successfully returned to Earth on July 24, 1969,
# splashing down in the Pacific Ocean.
# * The mission marked a historic achievement in space exploration, demonstrating
# the capability to land humans on another celestial body and return them safely
# to Earth.
#
# **Credible Sources:**
#
# 1. **NASA Official Website:** [www.nasa.gov](http://www.nasa.gov)
# * Article: "Apollo 11 Mission Overview"
# * Source: NASA's official website, which provides detailed information about
# the Apollo 11 mission, including timelines, crew bios, and mission objectives.
# 2. **Smithsonian National Air and Space Museum:**
# [www.nasm.si.edu](http://www.nasm.si.edu)
# * Article: "Apollo 11 Moon Landing"
# * Source: The Smithsonian National Air and Space Museum's website, which
# features a comprehensive article on the Apollo 11 mission, including
# photographs, videos, and artifacts.
# 3. **History.com:** [www.history.com](http://www.history.com)
# * Article: "Apollo 11 Moon Landing"
# * Source: History.com's website, which offers a detailed account of the Apollo
# 11 mission, including mission objectives, crew bios, and historical context

# %%
result = answer_with_llm(prompt_partior_longtail,system_prompt)
print("\n")
print("Long tail event\n")
print("==============================================================\n")
print(result)
# Out:
# Long tail event
#
# ==============================================================
#
# A very specific and interesting topic!
#
# Partior is a blockchain-based platform that enables secure, fast, and efficient
# cross-border transactions between banks and customers. Here's a summary of the
# latest advancements:
#
# **Latest Advancements:**
#
# 1. **Partior Network Upgrade:** In 2022, Partior announced a significant
# upgrade to its network, enhancing scalability, security, and performance. The
# upgrade enabled the platform to process higher transaction volumes, while
# maintaining its high level of security and compliance.
# 2. **Real-time Settlements:** Partior has successfully implemented real-time
# settlements for cross-border transactions, allowing for near-instant processing
# and reconciliation. This feature significantly reduces the time and cost
# associated with traditional cross-border payment systems.
# 3. **Tokenization and Interoperability:** Partior has introduced tokenization,
# enabling the creation of digital tokens that represent currencies, commodities,
# or securities. This feature enhances interoperability between different
# blockchain networks and systems, facilitating seamless cross-border
# transactions.
# 4. **Know-Your-Customer (KYC) and Anti-Money Laundering (AML) Compliance:**
# Partior has integrated advanced KYC and AML compliance features, ensuring that
# transactions are thoroughly vetted and compliant with global regulations.
# 5. **Partior's API and SDK:** The platform has introduced a robust API and
# Software Development Kit (SDK), allowing developers to easily integrate
# Partior's services into their applications, extending the platform's reach and
# adoption.
#
# **How Partior Handles Cross-Border Transfers:**
#
# 1. **Token Creation:** When a customer initiates a cross-border transaction,
# Partior creates a digital token representing the amount to be transferred.
# 2. **Smart Contract Execution:** The token is then transferred to a smart
# contract, which executes the transaction in real-time, ensuring that all
# parties are informed and updated.
# 3. **Token Settlement:** The token is finally settled on the recipient's
# account, with the funds being converted to the local currency.
# 4. **Reconciliation and Auditing:** Partior's platform ensures that all
# transactions are accurately reconciled and audited, providing transparency and
# security for all parties involved.
#
# **Benefits for Banks and Customers:**
#
# 1. **Faster and Cheaper Transactions:** Partior's platform enables real-time,
# low-cost cross-border transactions, reducing the time and cost associated with
# traditional payment systems.
# 2. **Increased Transparency and Security:** Partior's blockchain-based platform
# provides a transparent and secure transaction history, reducing the risk of
# errors and illicit activities.
# 3. **Improved Compliance:** Partior's advanced KYC and A
